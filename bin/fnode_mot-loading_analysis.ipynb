# %%
# %matplotlib notebook
from QDP import qdp
import os.path
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt
dp = '/home/ebert/jupyter-notebooks/FNode-data'

# %%
exp_name = ''
if exp_name:
    exp_date = '_'.join(exp_name.split('_')[:3])
    experiment_file = os.path.join(exp_date, exp_name, 'results.hdf5')
else:
    experiment_file = ''
q = qdp.QDP(base_data_path=dp)
q.load_data_file(experiment_file)
print "ivars: {}".format(q.experiments[0]['variable_list'])
# Out:
# name 'fort_exp' is not defined
# name 'rb_uwave_freq' is not defined
# ivars: [u'Iz']

# %%
means = []
means2 = []
for i in q.experiments[0]['iterations'].keys():
    r=0
    sig_data = q.experiments[0]['iterations'][i]['signal_data'][:,:,r,0]
    means.append(np.mean(sig_data, axis=0)[0])
    r=1
    sig_data = q.experiments[0]['iterations'][i]['signal_data'][:,:,r,0]
    means2.append(np.mean(sig_data, axis=0)[0])

# %%
f = plt.figure()
plt.plot(means/max(means))
plt.plot(means2/max(means2))
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
f = plt.figure()
plt.plot(means)
plt.plot(means2)
# Out:
# <img src="data:image/png;base64,..." width="640">
