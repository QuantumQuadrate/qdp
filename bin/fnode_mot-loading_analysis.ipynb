# %%
# %matplotlib ipympl
from QDP import qdp
import os.path
import numpy as np
from scipy.stats import poisson
import matplotlib.pyplot as plt
dp = '/home/ebert/jupyter-notebooks/FNode-data'

# %%
exp_name = ''
if exp_name:
    exp_date = '_'.join(exp_name.split('_')[:3])
    experiment_file = os.path.join(exp_date, exp_name, 'results.hdf5')
else:
    experiment_file = ''
q = qdp.QDP(base_data_path=dp)
q.load_data_file(experiment_file)
print "ivars: {}".format(q.experiments[0]['variable_list'])
# Out:
# data at: 2018_12_11/2018_12_11_10_27_38_iymotscan/results.hdf5
# name 'fort_exp' is not defined
# name 'rb_uwave_freq' is not defined
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# Possibly too many shots, analysis might need to be updated
# ivars: [u'Iy']

# %%
means = []
means2 = []
s=0
for i in q.experiments[0]['iterations'].keys():
    r=0
    sig_data = q.experiments[0]['iterations'][i]['signal_data'][:,:,r,0]
    means.append(np.mean(sig_data, axis=0)[s])
    r=1
    sig_data = q.experiments[0]['iterations'][i]['signal_data'][:,:,r,0]
    means2.append(np.mean(sig_data, axis=0)[s])

# %%
f = plt.figure()
plt.scatter(range(len(means)),means/max(means))
plt.scatter(range(len(means2)),means2/max(means2))
print max(means)
print max(means2)
# Out:
# FigureCanvasNbAgg()
# 686.8627450980392
# 1299.1960784313726

# %%
f = plt.figure()
plt.plot(means)
plt.plot(means2)
# Out:
# FigureCanvasNbAgg()
